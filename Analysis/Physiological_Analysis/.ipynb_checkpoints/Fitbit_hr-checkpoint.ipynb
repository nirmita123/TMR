# %%
import nbimporter
from fitbit import fitbitMeanHR
from fitbit import fitbitHR
from fitbit import plot_subject_wise
from fitbit import plot_time_wise
from fitbit import make_chunks
# baseFitbit="../../Reminessence_Physiological_Ananlysis/Data/Fitbit/"
# plots="../../Reminessence_Physiological_Ananlysis/Plots/"

# %% [markdown]
# ## Fitbit Sleep Data - 10 subjects

# %%
plot_subject_wise()
# Out:
# 63.146537435564674 62.02463581038048
# 1.7825262727523135 1.661302681098903

# %%
sleepDataC,sleepDataS = make_chunks()

# %%
plot_time_wise(sleepDataC,sleepDataS)
# Out:
# -0.6603712785728266 0.5142272204810282
# -0.6264225285127561 0.5359380582385888
# -0.23229693203238358 0.8179389585742902
# -0.1303661403950421 0.8971768691067024
